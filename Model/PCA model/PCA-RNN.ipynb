# %% [markdown]
# ## 1. Preparation

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### 1.1. Import data

# %%
df = pd.read_csv('Data/Data_10xsum3y.csv')
df
# Out:
#            Date  Temp  Turb   EC   pH  Colour  Bicarbonate  Silica   TKN  \
# 0      1985/6/1  13.0    32  512  7.8      12       204.00    16.7  0.68
# 1      1985/6/2  13.0    32  512  7.8      12       204.00    16.7  0.68
# 2      1985/6/3  13.0    32  512  7.8      12       204.00    16.7  0.68
# 3      1985/6/4  12.0    30  525  7.8      11       204.00    14.1  0.76
# 4      1985/6/5  12.0    30  525  7.8      11       204.00    14.1  0.76
# ...         ...   ...   ...  ...  ...     ...          ...     ...   ...
# 1076  1988/5/27  13.0   320  435  7.6     238       142.80    26.6  1.46
# 1077  1988/5/28  13.0   320  435  7.6     238       142.80    26.6  1.46
# 1078  1988/5/29  13.0   320  435  7.6     238       142.80    26.6  1.46
# 1079  1988/5/30  13.0   320  435  7.6     238       142.80    26.6  1.46
# 1080   1988/6/1  12.0   145  270  7.8      58       143.42    26.3  1.29
#
#       Sol_react_P  Flow    Cyano
# 0            0.26   230  32018.4
# 1            0.26   234  19029.6
# 2            0.26   238   6048.0
# 3            0.21   246   5292.0
# 4            0.21   246   4536.0
# ...           ...   ...      ...
# 1076         0.19   797      0.0
# 1077         0.19   824      0.0
# 1078         0.19   816      0.0
# 1079         0.19   812      0.0
# 1080         0.39   846      0.0
#
# [1081 rows x 12 columns]

# %%
data = df.iloc[:, 1:]
data = data.astype('float32')
data
# Out:
#       Temp   Turb     EC   pH  Colour  Bicarbonate     Silica   TKN  \
# 0     13.0   32.0  512.0  7.8    12.0   204.000000  16.700001  0.68
# 1     13.0   32.0  512.0  7.8    12.0   204.000000  16.700001  0.68
# 2     13.0   32.0  512.0  7.8    12.0   204.000000  16.700001  0.68
# 3     12.0   30.0  525.0  7.8    11.0   204.000000  14.100000  0.76
# 4     12.0   30.0  525.0  7.8    11.0   204.000000  14.100000  0.76
# ...    ...    ...    ...  ...     ...          ...        ...   ...
# 1076  13.0  320.0  435.0  7.6   238.0   142.800003  26.600000  1.46
# 1077  13.0  320.0  435.0  7.6   238.0   142.800003  26.600000  1.46
# 1078  13.0  320.0  435.0  7.6   238.0   142.800003  26.600000  1.46
# 1079  13.0  320.0  435.0  7.6   238.0   142.800003  26.600000  1.46
# 1080  12.0  145.0  270.0  7.8    58.0   143.419998  26.299999  1.29
#
#       Sol_react_P   Flow         Cyano
# 0            0.26  230.0  32018.400391
# 1            0.26  234.0  19029.599609
# 2            0.26  238.0   6048.000000
# 3            0.21  246.0   5292.000000
# 4            0.21  246.0   4536.000000
# ...           ...    ...           ...
# 1076         0.19  797.0      0.000000
# 1077         0.19  824.0      0.000000
# 1078         0.19  816.0      0.000000
# 1079         0.19  812.0      0.000000
# 1080         0.39  846.0      0.000000
#
# [1081 rows x 11 columns]

# %% [markdown]
# ## 2. Construction of data sets

# %% [markdown]
# ### 2.1. Processing outliers

# %%
from scipy.stats import zscore

# Calculate the Z-Score for each column
for col in data.columns:
    data['ZScored'] = zscore(data[col])
    rolling_mean = data[col].rolling(window=5, center=True, min_periods=1).mean()
    data[col] = data.apply(lambda row: rolling_mean[row.name] if abs(row['ZScored']) > 2 else row[col], axis=1)

data = data.drop(columns=['ZScored'])
data
# Out:
#       Temp        Turb     EC    pH  Colour  Bicarbonate     Silica   TKN  \
# 0     13.0   32.000000  512.0  7.80    12.0   204.000000  16.700001  0.68
# 1     13.0   32.000000  512.0  7.80    12.0   204.000000  16.700001  0.68
# 2     13.0   32.000000  512.0  7.80    12.0   204.000000  16.700001  0.68
# 3     12.0   30.000000  525.0  7.80    11.0   204.000000  14.100000  0.76
# 4     12.0   30.000000  525.0  7.80    11.0   204.000000  14.100000  0.76
# ...    ...         ...    ...   ...     ...          ...        ...   ...
# 1076  13.0  320.000000  435.0  7.60   238.0   142.800003  26.600000  1.46
# 1077  13.0  320.000000  435.0  7.60   238.0   142.800003  26.600000  1.46
# 1078  13.0  285.000000  435.0  7.64   202.0   142.800003  26.540000  1.46
# 1079  13.0  276.250000  435.0  7.65   193.0   142.800003  26.525000  1.46
# 1080  12.0  261.666667  380.0  7.80    58.0   143.419998  26.500000  1.29
#
#       Sol_react_P   Flow         Cyano
# 0        0.260000  230.0  32018.400391
# 1        0.260000  234.0  19029.599609
# 2        0.260000  238.0   6048.000000
# 3        0.210000  246.0   5292.000000
# 4        0.210000  246.0   4536.000000
# ...           ...    ...           ...
# 1076     0.190000  797.0      0.000000
# 1077     0.190000  824.0      0.000000
# 1078     0.190000  816.0      0.000000
# 1079     0.190000  812.0      0.000000
# 1080     0.256667  846.0      0.000000
#
# [1081 rows x 11 columns]

# %% [markdown]
# ### 2.2. Set features and targets

# %%
features = data[data.columns[:10]].values.copy()
targets = data['Cyano'].values.copy()

features.shape, targets.shape
# Out:
# ((1081, 10), (1081,))

# %% [markdown]
# ### 2.3. PCA

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
features_std = sc.fit_transform(features)
targets_std = sc.fit_transform(targets.reshape(-1, 1))

# %%
from sklearn.decomposition import PCA

n_components = 0.8
pca = PCA(n_components=n_components)
features_std_pca = pca.fit_transform(features_std)

plt.figure(figsize=(8, 6))
plt.scatter(features_std_pca[:, 0], features_std_pca[:, 1], c=targets_std, cmap='viridis')
plt.colorbar(label='Target')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Time Series Data')
plt.show()

print("The data shape after PCA conversion:", features_std_pca.shape)
print('Explained variance:',pca.explained_variance_)
print('Explained variance ratio:',pca.explained_variance_ratio_)
print('The proportion of information after dimensionality reduction in the original amount of information:',pca.explained_variance_ratio_.sum())
# Out:
# The data shape after PCA conversion: (1081, 5)
# Explained variance: [2.897254   2.37366941 1.34742475 0.93309801 0.79893125]
# Explained variance ratio: [0.28945738 0.23714736 0.13461783 0.09322348 0.07981922]
# The proportion of information after dimensionality reduction in the original amount of information: 0.8342652737065563

# %%
# Reverse standardization
features_pca = sc.inverse_transform(features_std_pca)

plt.figure(figsize=(8, 6))
plt.scatter(features_pca[:, 0], features_pca[:, 1], c=targets, cmap='viridis')
plt.colorbar(label='Target')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('PCA of Time Series Data (Inverse Transformed)')
plt.show()

print("The data shape after PCA conversion:", features_pca.shape)
# Out:
# The data shape after PCA conversion: (1081, 5)

# %% [markdown]
# ### 2.4. Split data set

# %%
win_size = 30 # Sliding window size
pre_times = 1  # Time step of prediction
feature_size = features_pca.shape[1]
target_size = 1

dataX = []
dataY = []
for index in range(len(data) - win_size - pre_times): 
    window_X = features_pca[index: index + win_size, :]        
    target_Y = targets[index + win_size:index + win_size + pre_times]
    dataX.append(window_X)
    dataY.append(target_Y)

dataX = np.array(dataX)
dataY = np.array(dataY)

dataX.shape, dataY.shape
# Out:
# ((1050, 30, 5), (1050, 1))

# %%
train_size = int(np.round(0.8 * dataX.shape[0]))
x_train = dataX[: train_size, :]
y_train = dataY[: train_size, :]
x_test = dataX[train_size:, :]
y_test = dataY[train_size:, :]

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((840, 30, 5), (840, 1), (210, 30, 5), (210, 1))

# %% [markdown]
# ### 2.5. Normalize the data

# %%
from sklearn.preprocessing import MinMaxScaler

x_train = MinMaxScaler().fit_transform(x_train.reshape(-1,feature_size))
y_train = MinMaxScaler().fit_transform(y_train)
x_test = MinMaxScaler().fit_transform(x_test.reshape(-1,feature_size))
y_test = MinMaxScaler().fit_transform(y_test)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((25200, 5), (840, 1), (6300, 5), (210, 1))

# %%
x_train_tensor = torch.tensor(x_train.reshape(-1,win_size,feature_size), dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train.reshape(-1,pre_times,target_size), dtype=torch.float32).to(device)
x_test_tensor = torch.tensor(x_test.reshape(-1,win_size,feature_size), dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test.reshape(-1,pre_times,target_size), dtype=torch.float32).to(device)

x_train_tensor.shape, y_train_tensor.shape, x_test_tensor.shape, y_test_tensor.shape
# Out:
# (torch.Size([840, 30, 5]),
#  torch.Size([840, 1, 1]),
#  torch.Size([210, 30, 5]),
#  torch.Size([210, 1, 1]))

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# ### 3.1. Constructing the model

# %% [markdown]
# #### RNN

# %%
class model_rnn(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, pre_times, dropout):
        super(model_rnn, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, pre_times)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.rnn(x, h0)
        out = self.dropout(out)
        out = self.fc(out[:, -1, :])
        return out

# %%
model = model_rnn(input_size=feature_size, hidden_size=128, num_layers=2, pre_times=pre_times, dropout=0).to(device)
loss_fn = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0005, weight_decay=1e-6)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.9)

# %% [markdown]
# ### 3.2. Training model

# %%
import time
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, TensorDataset

num_epochs = 500
train_loss_list = []
val_loss_list = []
early_stopping_patience = 20

# Define KFold
k_folds = 10
kf = KFold(n_splits=k_folds, shuffle=True)
KFold_epochs = []

start_time = time.time()
for fold, (train_indices, val_indices) in enumerate(kf.split(x_train_tensor, y_train_tensor)):
    print(f'Fold {fold+1}/{k_folds}')
    train_loader = DataLoader(TensorDataset(x_train_tensor[train_indices], y_train_tensor[train_indices]), batch_size=512, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_train_tensor[val_indices], y_train_tensor[val_indices]), batch_size=512, shuffle=True)
    best_val_loss = float('inf')
    patience_counter = 0
    for epoch in range(num_epochs):
        model.train()
        training_loss = 0
        for data in train_loader:
            x_train, y_train = data   
            optimizer.zero_grad() 
            y_train_pred = model(x_train)
            loss_training = loss_fn(y_train_pred.reshape(-1, target_size), y_train.reshape(-1, target_size))
            loss_training.backward() 
            optimizer.step()
            training_loss += loss_training.item()
        train_loss_list.append(training_loss / len(train_loader))
        if lr_scheduler is not None:
            lr_scheduler.step()

        model.eval()
        valing_loss = 0
        val_losses = [] 
        with torch.no_grad():
            for data in val_loader:
                x_val, y_val = data
                y_val_pred = model(x_val)
                loss_valing = loss_fn(y_val_pred.reshape(-1, target_size), y_val.reshape(-1, target_size))
                valing_loss += loss_valing.item()
                val_losses.append(loss_valing.item())
        val_loss_list.append(valing_loss / len(val_loader))
        if (epoch+1) % 10 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Learning Rate: {lr_scheduler.get_last_lr()}, Training Loss: {training_loss / len(train_loader):.4f}, Valing Loss: {valing_loss / len(val_loader):.4f}")
        elif (epoch+1) == 1:  
            print(f"Epoch [{epoch+1}/{num_epochs}], Learning Rate: {lr_scheduler.get_last_lr()}, Training Loss: {training_loss / len(train_loader):.4f}, Valing Loss: {valing_loss / len(val_loader):.4f}")
        valing_loss = valing_loss / len(val_loader)
        if valing_loss < best_val_loss:
            best_val_loss = valing_loss
            torch.save(model.state_dict(), 'PCA-RNN.pth')
            patience_counter = 0  
        else:
            patience_counter += 1
        if patience_counter >= early_stopping_patience:
            print(f'Early stopping at epoch {epoch+1}')
            KFold_epochs.append(epoch+1)
            break
        elif epoch == num_epochs - 1:
            KFold_epochs.append(epoch+1)
end_time = time.time()

print(f"Total epochs: {np.sum(KFold_epochs)}")
time_per_epoch = (end_time-start_time)/(np.sum(KFold_epochs))
print(f"Training time: {end_time-start_time}s")
print(f"Time per epoch: {time_per_epoch}s")
print("="*20, "Training Finished", "="*20)
# Out:
# Fold 1/10
# Epoch [1/500], Learning Rate: [0.0005], Training Loss: 0.0339, Valing Loss: 0.0253
# Epoch [10/500], Learning Rate: [0.00045000000000000004], Training Loss: 0.0271, Valing Loss: 0.0175
# Epoch [20/500], Learning Rate: [0.00040500000000000003], Training Loss: 0.0256, Valing Loss: 0.0157
# Epoch [30/500], Learning Rate: [0.0003645], Training Loss: 0.0260, Valing Loss: 0.0158
# Epoch [40/500], Learning Rate: [0.00032805000000000003], Training Loss: 0.0246, Valing Loss: 0.0155
# Epoch [50/500], Learning Rate: [0.000295245], Training Loss: 0.0241, Valing Loss: 0.0162
# Early stopping at epoch 56
# Fold 2/10
# Epoch [1/500], Learning Rate: [0.000295245], Training Loss: 0.0217, Valing Loss: 0.0161
# Epoch [10/500], Learning Rate: [0.0002657205], Training Loss: 0.0177, Valing Loss: 0.0072
# Epoch [20/500], Learning Rate: [0.00023914845], Training Loss: 0.0133, Valing Loss: 0.0082
# Epoch [30/500], Learning Rate: [0.000215233605], Training Loss: 0.0147, Valing Loss: 0.0059
# Epoch [40/500], Learning Rate: [0.0001937102445], Training Loss: 0.0119, Valing Loss: 0.0052
# Epoch [20/500], Learning Rate: [1.1092656172311322e-06], Training Loss: 0.0043, Valing Loss: 0.0117
# Early stopping at epoch 21
# Fold 8/10
# Epoch [1/500], Learning Rate: [1.1092656172311322e-06], Training Loss: 0.0050, Valing Loss: 0.0071
# Epoch [10/500], Learning Rate: [9.98339055508019e-07], Training Loss: 0.0053, Valing Loss: 0.0071
# Epoch [20/500], Learning Rate: [8.985051499572171e-07], Training Loss: 0.0049, Valing Loss: 0.0071
# Epoch [30/500], Learning Rate: [8.086546349614954e-07], Training Loss: 0.0051, Valing Loss: 0.0071
# Early stopping at epoch 35
# Fold 9/10
# Epoch [1/500], Learning Rate: [7.277891714653459e-07], Training Loss: 0.0051, Valing Loss: 0.0072
# Epoch [10/500], Learning Rate: [6.550102543188112e-07], Training Loss: 0.0052, Valing Loss: 0.0073
# Epoch [20/500], Learning Rate: [5.895092288869302e-07], Training Loss: 0.0051, Valing Loss: 0.0074
# Early stopping at epoch 21
# Fold 10/10
# Epoch [1/500], Learning Rate: [5.895092288869302e-07], Training Loss: 0.0055, Valing Loss: 0.0024
# Epoch [10/500], Learning Rate: [5.305583059982371e-07], Training Loss: 0.0057, Valing Loss: 0.0025
# Epoch [20/500], Learning Rate: [4.775024753984134e-07], Training Loss: 0.0054, Valing Loss: 0.0025
# Early stopping at epoch 21
# Total epochs: 662
# Training time: 9.848862648010254s
# Time per epoch: 0.014877436024184674s
# ==================== Training Finished ====================

# %% [markdown]
# ## 4. Model evaluation

# %% [markdown]
# ### 4.1. Loss graph

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5), dpi=100)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams.update({'font.size': 14})
plt.plot(train_loss_list, label='Train Loss', color='#1b9e77')
plt.plot(val_loss_list, label='val Loss', color='#FFA319')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss')
plt.show()

# %%
# Plot the training set results
y_train_pred = model(x_train_tensor)
predicted_train = y_train_pred.cpu().detach().numpy().reshape(-1, target_size)
actual_train = y_train_tensor.cpu().detach().numpy().reshape(-1, target_size)

plt.figure(figsize=(12, 6))
plt.plot(actual_train[:1000], label=f'Actual Train', color='#33BBEE')
plt.plot(predicted_train[:1000], label=f'Predicted Train', color='#fd206e')
plt.legend()
plt.title(f'Train')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2. Use the model to predict

# %%
y_test_pred = model(x_test_tensor)
predicted_test = y_test_pred.cpu().detach().numpy().reshape(-1, target_size)
actual_test = y_test_tensor.cpu().detach().numpy().reshape(-1, target_size)

plt.figure(figsize=(12, 6), dpi=100)
plt.plot(actual_test[:1000], label='True', color='#33BBEE')
plt.plot(predicted_test[:1000], label='Predicted', color='#fd206e')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.title('Test')
plt.show()

# %% [markdown]
# ### 4.3. Evaluation index

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error

print("MSE: ", mean_squared_error(actual_test, predicted_test))
print("R2 Score: ", r2_score(actual_test, predicted_test))
print("MAE: ", mean_absolute_error(actual_test, predicted_test))
print("MedAE: ", median_absolute_error(actual_test, predicted_test))
# Out:
# MSE:  0.04500338
# R2 Score:  0.45766246454818027
# MAE:  0.14229764
# MedAE:  0.100132585
