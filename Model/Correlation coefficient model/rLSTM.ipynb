# %% [markdown]
# ## 1. Preparation

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### 1.1. Import data

# %%
df = pd.read_csv('Data/Data_5xsum3y.csv')
df
# Out:
#            Date  Temp   EC   pH  Bicarbonate   TKN    Cyano
# 0      1985/6/1  13.0  512  7.8       204.00  0.68  32018.4
# 1      1985/6/2  13.0  512  7.8       204.00  0.68  19029.6
# 2      1985/6/3  13.0  512  7.8       204.00  0.68   6048.0
# 3      1985/6/4  12.0  525  7.8       204.00  0.76   5292.0
# 4      1985/6/5  12.0  525  7.8       204.00  0.76   4536.0
# ...         ...   ...  ...  ...          ...   ...      ...
# 1076  1988/5/27  13.0  435  7.6       142.80  1.46      0.0
# 1077  1988/5/28  13.0  435  7.6       142.80  1.46      0.0
# 1078  1988/5/29  13.0  435  7.6       142.80  1.46      0.0
# 1079  1988/5/30  13.0  435  7.6       142.80  1.46      0.0
# 1080   1988/6/1  12.0  270  7.8       143.42  1.29      0.0
#
# [1081 rows x 7 columns]

# %%
data = df.iloc[:, 1:]
data = data.astype('float32')
data
# Out:
#       Temp     EC   pH  Bicarbonate   TKN         Cyano
# 0     13.0  512.0  7.8   204.000000  0.68  32018.400391
# 1     13.0  512.0  7.8   204.000000  0.68  19029.599609
# 2     13.0  512.0  7.8   204.000000  0.68   6048.000000
# 3     12.0  525.0  7.8   204.000000  0.76   5292.000000
# 4     12.0  525.0  7.8   204.000000  0.76   4536.000000
# ...    ...    ...  ...          ...   ...           ...
# 1076  13.0  435.0  7.6   142.800003  1.46      0.000000
# 1077  13.0  435.0  7.6   142.800003  1.46      0.000000
# 1078  13.0  435.0  7.6   142.800003  1.46      0.000000
# 1079  13.0  435.0  7.6   142.800003  1.46      0.000000
# 1080  12.0  270.0  7.8   143.419998  1.29      0.000000
#
# [1081 rows x 6 columns]

# %% [markdown]
# ## 2. Construction of data sets

# %% [markdown]
# ### 2.1. Processing outliers

# %%
from scipy.stats import zscore

# Calculate the Z-Score for each column
for col in data.columns:
    data['ZScored'] = zscore(data[col])
    rolling_mean = data[col].rolling(window=5, center=True, min_periods=1).mean()
    data[col] = data.apply(lambda row: rolling_mean[row.name] if abs(row['ZScored']) > 2 else row[col], axis=1)

data = data.drop(columns=['ZScored'])
data
# Out:
#       Temp     EC    pH  Bicarbonate   TKN         Cyano
# 0     13.0  512.0  7.80   204.000000  0.68  32018.400391
# 1     13.0  512.0  7.80   204.000000  0.68  19029.599609
# 2     13.0  512.0  7.80   204.000000  0.68   6048.000000
# 3     12.0  525.0  7.80   204.000000  0.76   5292.000000
# 4     12.0  525.0  7.80   204.000000  0.76   4536.000000
# ...    ...    ...   ...          ...   ...           ...
# 1076  13.0  435.0  7.60   142.800003  1.46      0.000000
# 1077  13.0  435.0  7.60   142.800003  1.46      0.000000
# 1078  13.0  435.0  7.64   142.800003  1.46      0.000000
# 1079  13.0  435.0  7.65   142.800003  1.46      0.000000
# 1080  12.0  380.0  7.80   143.419998  1.29      0.000000
#
# [1081 rows x 6 columns]

# %% [markdown]
# ### 2.2. Set features and targets

# %%
feature_size = 5
target_size = 1

features = data[data.columns[:feature_size]].values.copy()
targets = data['Cyano'].values.copy()

features.shape, targets.shape
# Out:
# ((1081, 5), (1081,))

# %% [markdown]
# ### 2.3. Split data set

# %%
win_size = 5 # Sliding window size
pre_times = 1 # Time step of prediction

dataX = []  
dataY = []  
for index in range(len(data) - win_size - pre_times): 
    window_X = features[index: index + win_size, :]        
    target_Y = targets[index + win_size:index + win_size + pre_times]
    dataX.append(window_X)
    dataY.append(target_Y)

dataX = np.array(dataX)
dataY = np.array(dataY)

dataX.shape, dataY.shape
# Out:
# ((1075, 5, 5), (1075, 1))

# %%
train_size = int(np.round(0.8 * dataX.shape[0]))
x_train = dataX[: train_size, :]
y_train = dataY[: train_size, :]
x_test = dataX[train_size:, :]
y_test = dataY[train_size:, :]

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((860, 5, 5), (860, 1), (215, 5, 5), (215, 1))

# %% [markdown]
# ### 2.4. Normalize the data

# %%
from sklearn.preprocessing import MinMaxScaler

x_train = MinMaxScaler().fit_transform(x_train.reshape(-1,features.shape[1]))
y_train = MinMaxScaler().fit_transform(y_train)
x_test = MinMaxScaler().fit_transform(x_test.reshape(-1,features.shape[1]))
y_test = MinMaxScaler().fit_transform(y_test)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((4300, 5), (860, 1), (1075, 5), (215, 1))

# %%
x_train_tensor = torch.tensor(x_train.reshape(-1,win_size,features.shape[1]), dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train.reshape(-1,pre_times,target_size), dtype=torch.float32).to(device)
x_test_tensor = torch.tensor(x_test.reshape(-1,win_size,features.shape[1]), dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test.reshape(-1,pre_times,target_size), dtype=torch.float32).to(device)

x_train_tensor.shape, y_train_tensor.shape, x_test_tensor.shape, y_test_tensor.shape
# Out:
# (torch.Size([860, 5, 5]),
#  torch.Size([860, 1, 1]),
#  torch.Size([215, 5, 5]),
#  torch.Size([215, 1, 1]))

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# ### 3.1. Constructing the model

# %% [markdown]
# #### LSTM

# %%
class model_lstm(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, pre_times, Dropout):
        super(model_lstm, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(p=Dropout)
        self.fc = nn.Linear(hidden_size, pre_times)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out)
        out = self.fc(out[:, -1, :])        
        return out

# %%
model = model_lstm(input_size=feature_size, hidden_size=64, num_layers=2, pre_times=pre_times, Dropout=0.1).to(device)
loss_fn = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.003, weight_decay=1e-6)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.9)

# %% [markdown]
# ### 3.2. Training model

# %%
import time
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, TensorDataset

num_epochs = 500
train_loss_list = []
val_loss_list = []
early_stopping_patience = 50

# Define KFold
k_folds = 10
kf = KFold(n_splits=k_folds, shuffle=True)
KFold_epochs = []

start_time = time.time()
for fold, (train_indices, val_indices) in enumerate(kf.split(x_train_tensor, y_train_tensor)):
    print(f'Fold {fold+1}/{k_folds}')
    train_loader = DataLoader(TensorDataset(x_train_tensor[train_indices], y_train_tensor[train_indices]), batch_size=512, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_train_tensor[val_indices], y_train_tensor[val_indices]), batch_size=512, shuffle=True)
    best_val_loss = float('inf') 
    patience_counter = 0
    for epoch in range(num_epochs):
        model.train()
        training_loss = 0
        for data in train_loader:
            x_train, y_train = data
            optimizer.zero_grad()
            y_train_pred = model(x_train)
            loss_training = loss_fn(y_train_pred.reshape(-1, target_size), y_train.reshape(-1, target_size))
            loss_training.backward()
            optimizer.step()
            training_loss += loss_training.item()
        train_loss_list.append(training_loss / len(train_loader))
        if lr_scheduler is not None:
            lr_scheduler.step()

        model.eval()
        valing_loss = 0
        val_losses = [] 
        with torch.no_grad():
            for data in val_loader:
                x_val, y_val = data
                y_val_pred = model(x_val)
                loss_valing = loss_fn(y_val_pred.reshape(-1, target_size), y_val.reshape(-1, target_size))
                valing_loss += loss_valing.item()
                val_losses.append(loss_valing.item())

        val_loss_list.append(valing_loss / len(val_loader))
        if (epoch+1) % 10 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Learning Rate: {lr_scheduler.get_last_lr()}, Training Loss: {training_loss / len(train_loader):.4f}, Valing Loss: {valing_loss / len(val_loader):.4f}")
        elif (epoch+1) == 1:  
            print(f"Epoch [{epoch+1}/{num_epochs}], Learning Rate: {lr_scheduler.get_last_lr()}, Training Loss: {training_loss / len(train_loader):.4f}, Valing Loss: {valing_loss / len(val_loader):.4f}")
        valing_loss = valing_loss / len(val_loader)
        if valing_loss < best_val_loss:
            best_val_loss = valing_loss
            torch.save(model.state_dict(), 'rLSTM.pth')
            patience_counter = 0 
        else:
            patience_counter += 1  
        if patience_counter >= early_stopping_patience:
            print(f'Early stopping at epoch {epoch+1}')
            KFold_epochs.append(epoch+1)
            break
        elif epoch == num_epochs - 1:
            KFold_epochs.append(epoch+1)
end_time = time.time()

print(f"Total epochs: {np.sum(KFold_epochs)}")
time_per_epoch = (end_time-start_time)/(np.sum(KFold_epochs))
print(f"Training time: {end_time-start_time}s")
print(f"Time per epoch: {time_per_epoch}s")
print("="*20, "Training Finished", "="*20)
# Out:
# Fold 1/10
# Epoch [1/500], Learning Rate: [0.003], Training Loss: 0.0338, Valing Loss: 0.0250
# Epoch [10/500], Learning Rate: [0.003], Training Loss: 0.0270, Valing Loss: 0.0253
# Epoch [20/500], Learning Rate: [0.003], Training Loss: 0.0249, Valing Loss: 0.0257
# Epoch [30/500], Learning Rate: [0.003], Training Loss: 0.0221, Valing Loss: 0.0242
# Epoch [40/500], Learning Rate: [0.003], Training Loss: 0.0221, Valing Loss: 0.0238
# Epoch [50/500], Learning Rate: [0.0027], Training Loss: 0.0217, Valing Loss: 0.0227
# Epoch [60/500], Learning Rate: [0.0027], Training Loss: 0.0182, Valing Loss: 0.0210
# Epoch [70/500], Learning Rate: [0.0027], Training Loss: 0.0172, Valing Loss: 0.0198
# Epoch [80/500], Learning Rate: [0.0027], Training Loss: 0.0180, Valing Loss: 0.0176
# Epoch [90/500], Learning Rate: [0.0027], Training Loss: 0.0167, Valing Loss: 0.0164
# Epoch [100/500], Learning Rate: [0.0024300000000000003], Training Loss: 0.0149, Valing Loss: 0.0137
# Epoch [110/500], Learning Rate: [0.0024300000000000003], Training Loss: 0.0126, Valing Loss: 0.0105
# Epoch [120/500], Learning Rate: [0.0024300000000000003], Training Loss: 0.0119, Valing Loss: 0.0088
# Epoch [130/500], Learning Rate: [0.0024300000000000003], Training Loss: 0.0100, Valing Loss: 0.0069
# Epoch [140/500], Learning Rate: [0.0024300000000000003], Training Loss: 0.0098, Valing Loss: 0.0067
# Epoch [150/500], Learning Rate: [0.002187], Training Loss: 0.0105, Valing Loss: 0.0064
# Epoch [160/500], Learning Rate: [0.002187], Training Loss: 0.0104, Valing Loss: 0.0065
# Epoch [170/500], Learning Rate: [0.002187], Training Loss: 0.0103, Valing Loss: 0.0068
# Epoch [180/500], Learning Rate: [0.002187], Training Loss: 0.0092, Valing Loss: 0.0071
# Epoch [190/500], Learning Rate: [0.002187], Training Loss: 0.0099, Valing Loss: 0.0065
# Epoch [200/500], Learning Rate: [0.0019683], Training Loss: 0.0087, Valing Loss: 0.0061
# Epoch [210/500], Learning Rate: [0.0019683], Training Loss: 0.0093, Valing Loss: 0.0067
# Epoch [220/500], Learning Rate: [0.0019683], Training Loss: 0.0099, Valing Loss: 0.0060
# Epoch [230/500], Learning Rate: [0.0019683], Training Loss: 0.0089, Valing Loss: 0.0058
# Epoch [240/500], Learning Rate: [0.0019683], Training Loss: 0.0095, Valing Loss: 0.0065
# Epoch [250/500], Learning Rate: [0.00177147], Training Loss: 0.0105, Valing Loss: 0.0059
# Epoch [260/500], Learning Rate: [0.00177147], Training Loss: 0.0091, Valing Loss: 0.0062
# Epoch [270/500], Learning Rate: [0.00177147], Training Loss: 0.0095, Valing Loss: 0.0061
# Epoch [280/500], Learning Rate: [0.00177147], Training Loss: 0.0091, Valing Loss: 0.0058
# Epoch [290/500], Learning Rate: [0.00177147], Training Loss: 0.0084, Valing Loss: 0.0060
# Epoch [300/500], Learning Rate: [0.0015943230000000001], Training Loss: 0.0091, Valing Loss: 0.0057
# Epoch [310/500], Learning Rate: [0.0015943230000000001], Training Loss: 0.0085, Valing Loss: 0.0059
# Epoch [320/500], Learning Rate: [0.0015943230000000001], Training Loss: 0.0085, Valing Loss: 0.0057
# Epoch [330/500], Learning Rate: [0.0015943230000000001], Training Loss: 0.0086, Valing Loss: 0.0058
# Epoch [340/500], Learning Rate: [0.0015943230000000001], Training Loss: 0.0080, Valing Loss: 0.0058
# Epoch [350/500], Learning Rate: [0.0014348907], Training Loss: 0.0081, Valing Loss: 0.0060
# Epoch [360/500], Learning Rate: [0.0014348907], Training Loss: 0.0080, Valing Loss: 0.0054
# Epoch [370/500], Learning Rate: [0.0014348907], Training Loss: 0.0084, Valing Loss: 0.0058
# Epoch [380/500], Learning Rate: [0.0014348907], Training Loss: 0.0082, Valing Loss: 0.0063
# Epoch [390/500], Learning Rate: [0.0014348907], Training Loss: 0.0083, Valing Loss: 0.0053
# Epoch [400/500], Learning Rate: [0.00129140163], Training Loss: 0.0086, Valing Loss: 0.0052
# Epoch [410/500], Learning Rate: [0.00129140163], Training Loss: 0.0086, Valing Loss: 0.0056
# Epoch [420/500], Learning Rate: [0.00129140163], Training Loss: 0.0080, Valing Loss: 0.0053
# Epoch [430/500], Learning Rate: [0.00129140163], Training Loss: 0.0078, Valing Loss: 0.0052
# Epoch [440/500], Learning Rate: [0.00129140163], Training Loss: 0.0075, Valing Loss: 0.0052
# Epoch [450/500], Learning Rate: [0.001162261467], Training Loss: 0.0078, Valing Loss: 0.0050
# Epoch [460/500], Learning Rate: [0.001162261467], Training Loss: 0.0072, Valing Loss: 0.0055
# Epoch [470/500], Learning Rate: [0.001162261467], Training Loss: 0.0065, Valing Loss: 0.0048
# Epoch [480/500], Learning Rate: [0.001162261467], Training Loss: 0.0071, Valing Loss: 0.0050
# Epoch [490/500], Learning Rate: [0.001162261467], Training Loss: 0.0071, Valing Loss: 0.0051
# Epoch [500/500], Learning Rate: [0.0010460353203000001], Training Loss: 0.0066, Valing Loss: 0.0044
# Fold 2/10
# Epoch [1/500], Learning Rate: [0.0010460353203000001], Training Loss: 0.0057, Valing Loss: 0.0076
# Epoch [10/500], Learning Rate: [0.0010460353203000001], Training Loss: 0.0062, Valing Loss: 0.0070
# Epoch [20/500], Learning Rate: [0.0010460353203000001], Training Loss: 0.0063, Valing Loss: 0.0068
# Epoch [30/500], Learning Rate: [0.0010460353203000001], Training Loss: 0.0061, Valing Loss: 0.0069
# Epoch [40/500], Learning Rate: [0.0010460353203000001], Training Loss: 0.0059, Valing Loss: 0.0071
# Epoch [50/500], Learning Rate: [0.0009414317882700001], Training Loss: 0.0061, Valing Loss: 0.0085
# Epoch [60/500], Learning Rate: [0.0009414317882700001], Training Loss: 0.0058, Valing Loss: 0.0067
# Epoch [70/500], Learning Rate: [0.0009414317882700001], Training Loss: 0.0057, Valing Loss: 0.0080
# Epoch [80/500], Learning Rate: [0.0009414317882700001], Training Loss: 0.0055, Valing Loss: 0.0072
# Epoch [90/500], Learning Rate: [0.0009414317882700001], Training Loss: 0.0052, Valing Loss: 0.0073
# Epoch [100/500], Learning Rate: [0.0008472886094430002], Training Loss: 0.0050, Valing Loss: 0.0053
# Epoch [110/500], Learning Rate: [0.0008472886094430002], Training Loss: 0.0057, Valing Loss: 0.0068
# Epoch [120/500], Learning Rate: [0.0008472886094430002], Training Loss: 0.0057, Valing Loss: 0.0073
# Epoch [130/500], Learning Rate: [0.0008472886094430002], Training Loss: 0.0050, Valing Loss: 0.0071
# Epoch [140/500], Learning Rate: [0.0008472886094430002], Training Loss: 0.0050, Valing Loss: 0.0068
# Epoch [150/500], Learning Rate: [0.0007625597484987002], Training Loss: 0.0052, Valing Loss: 0.0063
# Epoch [160/500], Learning Rate: [0.0007625597484987002], Training Loss: 0.0047, Valing Loss: 0.0074
# Epoch [170/500], Learning Rate: [0.0007625597484987002], Training Loss: 0.0053, Valing Loss: 0.0050
# Epoch [180/500], Learning Rate: [0.0007625597484987002], Training Loss: 0.0048, Valing Loss: 0.0054
# Early stopping at epoch 189
# Fold 3/10
# Epoch [1/500], Learning Rate: [0.0007625597484987002], Training Loss: 0.0047, Valing Loss: 0.0062
# Epoch [10/500], Learning Rate: [0.0007625597484987002], Training Loss: 0.0042, Valing Loss: 0.0087
# Epoch [20/500], Learning Rate: [0.0006863037736488302], Training Loss: 0.0043, Valing Loss: 0.0049
# Epoch [30/500], Learning Rate: [0.0006863037736488302], Training Loss: 0.0047, Valing Loss: 0.0048
# Epoch [40/500], Learning Rate: [0.0006863037736488302], Training Loss: 0.0047, Valing Loss: 0.0057
# Epoch [50/500], Learning Rate: [0.0006863037736488302], Training Loss: 0.0052, Valing Loss: 0.0058
# Epoch [60/500], Learning Rate: [0.0006863037736488302], Training Loss: 0.0042, Valing Loss: 0.0055
# Epoch [70/500], Learning Rate: [0.0006176733962839472], Training Loss: 0.0050, Valing Loss: 0.0055
# Early stopping at epoch 75
# Fold 4/10
# Epoch [1/500], Learning Rate: [0.0006176733962839472], Training Loss: 0.0045, Valing Loss: 0.0019
# Epoch [10/500], Learning Rate: [0.0006176733962839472], Training Loss: 0.0050, Valing Loss: 0.0028
# Epoch [20/500], Learning Rate: [0.0006176733962839472], Training Loss: 0.0043, Valing Loss: 0.0025
# Epoch [30/500], Learning Rate: [0.0006176733962839472], Training Loss: 0.0045, Valing Loss: 0.0028
# Epoch [40/500], Learning Rate: [0.0005559060566555524], Training Loss: 0.0046, Valing Loss: 0.0021
# Epoch [50/500], Learning Rate: [0.0005559060566555524], Training Loss: 0.0049, Valing Loss: 0.0021
# Epoch [60/500], Learning Rate: [0.0005559060566555524], Training Loss: 0.0045, Valing Loss: 0.0026
# Epoch [70/500], Learning Rate: [0.0005559060566555524], Training Loss: 0.0044, Valing Loss: 0.0023
# Epoch [80/500], Learning Rate: [0.0005559060566555524], Training Loss: 0.0042, Valing Loss: 0.0028
# Early stopping at epoch 85
# Fold 5/10
# Epoch [1/500], Learning Rate: [0.0005003154509899972], Training Loss: 0.0036, Valing Loss: 0.0049
# Epoch [10/500], Learning Rate: [0.0005003154509899972], Training Loss: 0.0047, Valing Loss: 0.0061
# Epoch [20/500], Learning Rate: [0.0005003154509899972], Training Loss: 0.0041, Valing Loss: 0.0060
# Epoch [30/500], Learning Rate: [0.0005003154509899972], Training Loss: 0.0037, Valing Loss: 0.0058
# Epoch [40/500], Learning Rate: [0.0005003154509899972], Training Loss: 0.0039, Valing Loss: 0.0063
# Epoch [50/500], Learning Rate: [0.0005003154509899972], Training Loss: 0.0040, Valing Loss: 0.0056
# Early stopping at epoch 52
# Fold 6/10
# Epoch [1/500], Learning Rate: [0.00045028390589099747], Training Loss: 0.0040, Valing Loss: 0.0050
# Epoch [10/500], Learning Rate: [0.00045028390589099747], Training Loss: 0.0040, Valing Loss: 0.0053
# Epoch [20/500], Learning Rate: [0.00045028390589099747], Training Loss: 0.0042, Valing Loss: 0.0051
# Epoch [30/500], Learning Rate: [0.00045028390589099747], Training Loss: 0.0038, Valing Loss: 0.0051
# Epoch [40/500], Learning Rate: [0.00045028390589099747], Training Loss: 0.0039, Valing Loss: 0.0053
# Epoch [50/500], Learning Rate: [0.0004052555153018977], Training Loss: 0.0038, Valing Loss: 0.0050
# Early stopping at epoch 52
# Fold 7/10
# Epoch [1/500], Learning Rate: [0.0004052555153018977], Training Loss: 0.0046, Valing Loss: 0.0037
# Epoch [10/500], Learning Rate: [0.0004052555153018977], Training Loss: 0.0040, Valing Loss: 0.0035
# Epoch [20/500], Learning Rate: [0.0004052555153018977], Training Loss: 0.0037, Valing Loss: 0.0041
# Epoch [30/500], Learning Rate: [0.0004052555153018977], Training Loss: 0.0039, Valing Loss: 0.0031
# Epoch [40/500], Learning Rate: [0.0004052555153018977], Training Loss: 0.0038, Valing Loss: 0.0034
# Epoch [50/500], Learning Rate: [0.00036472996377170795], Training Loss: 0.0040, Valing Loss: 0.0038
# Early stopping at epoch 54
# Fold 8/10
# Epoch [1/500], Learning Rate: [0.00036472996377170795], Training Loss: 0.0036, Valing Loss: 0.0065
# Epoch [10/500], Learning Rate: [0.00036472996377170795], Training Loss: 0.0035, Valing Loss: 0.0058
# Epoch [20/500], Learning Rate: [0.00036472996377170795], Training Loss: 0.0038, Valing Loss: 0.0057
# Epoch [30/500], Learning Rate: [0.00036472996377170795], Training Loss: 0.0041, Valing Loss: 0.0065
# Epoch [40/500], Learning Rate: [0.00036472996377170795], Training Loss: 0.0040, Valing Loss: 0.0056
# Epoch [50/500], Learning Rate: [0.00032825696739453717], Training Loss: 0.0037, Valing Loss: 0.0059
# Epoch [60/500], Learning Rate: [0.00032825696739453717], Training Loss: 0.0038, Valing Loss: 0.0057
# Epoch [70/500], Learning Rate: [0.00032825696739453717], Training Loss: 0.0039, Valing Loss: 0.0048
# Epoch [80/500], Learning Rate: [0.00032825696739453717], Training Loss: 0.0037, Valing Loss: 0.0061
# Early stopping at epoch 86
# Fold 9/10
# Epoch [1/500], Learning Rate: [0.00032825696739453717], Training Loss: 0.0033, Valing Loss: 0.0042
# Epoch [10/500], Learning Rate: [0.00029543127065508344], Training Loss: 0.0039, Valing Loss: 0.0033
# Epoch [20/500], Learning Rate: [0.00029543127065508344], Training Loss: 0.0039, Valing Loss: 0.0035
# Epoch [30/500], Learning Rate: [0.00029543127065508344], Training Loss: 0.0039, Valing Loss: 0.0042
# Epoch [40/500], Learning Rate: [0.00029543127065508344], Training Loss: 0.0037, Valing Loss: 0.0044
# Epoch [50/500], Learning Rate: [0.00029543127065508344], Training Loss: 0.0041, Valing Loss: 0.0040
# Epoch [60/500], Learning Rate: [0.0002658881435895751], Training Loss: 0.0039, Valing Loss: 0.0035
# Early stopping at epoch 60
# Fold 10/10
# Epoch [1/500], Learning Rate: [0.0002658881435895751], Training Loss: 0.0037, Valing Loss: 0.0046
# Epoch [10/500], Learning Rate: [0.0002658881435895751], Training Loss: 0.0040, Valing Loss: 0.0046
# Epoch [20/500], Learning Rate: [0.0002658881435895751], Training Loss: 0.0036, Valing Loss: 0.0049
# Epoch [30/500], Learning Rate: [0.0002658881435895751], Training Loss: 0.0037, Valing Loss: 0.0048
# Epoch [40/500], Learning Rate: [0.0002658881435895751], Training Loss: 0.0037, Valing Loss: 0.0048
# Epoch [50/500], Learning Rate: [0.0002392993292306176], Training Loss: 0.0036, Valing Loss: 0.0049
# Epoch [60/500], Learning Rate: [0.0002392993292306176], Training Loss: 0.0035, Valing Loss: 0.0052
# Early stopping at epoch 61
# Total epochs: 1214
# Training time: 20.10604429244995s
# Time per epoch: 0.016561815726894524s
# ==================== Training Finished ====================

# %% [markdown]
# ## 4. Model evaluation

# %% [markdown]
# ### 4.1. Loss graph

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5), dpi=100)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams.update({'font.size': 14})
plt.plot(train_loss_list, label='Train Loss', color='#1b9e77')
plt.plot(val_loss_list, label='val Loss', color='#FFA319')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss')
plt.show()

# %%
# Plot the training set results
y_train_pred = model(x_train_tensor)
predicted_train = y_train_pred.cpu().detach().numpy().reshape(-1, target_size)
actual_train = y_train_tensor.cpu().detach().numpy().reshape(-1, target_size)

plt.figure(figsize=(12, 6))
plt.plot(actual_train[:2000], label=f'Actual Train', color='#33BBEE')
plt.plot(predicted_train[:2000], label=f'Predicted Train', color='#fd206e')
plt.legend()
plt.title(f'Train')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2. Use the model to predict

# %%
y_test_pred = model(x_test_tensor)
predicted_test = y_test_pred.cpu().detach().numpy().reshape(-1, target_size)
actual_test = y_test_tensor.cpu().detach().numpy().reshape(-1, target_size)

plt.figure(figsize=(12, 6), dpi=100)
plt.plot(actual_test[:1000], label='True', color='#33BBEE')
plt.plot(predicted_test[:1000], label='Predicted', color='#fd206e')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.title('Test')
plt.show()

# %% [markdown]
# ### 4.3. Evaluation index

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error

print("MSE: ", mean_squared_error(actual_test, predicted_test))
print("R2 Score: ", r2_score(actual_test, predicted_test))
print("MAE: ", mean_absolute_error(actual_test, predicted_test))
print("MedAE: ", median_absolute_error(actual_test, predicted_test))
# Out:
# MSE:  0.04433368
# R2 Score:  0.45701572804046053
# MAE:  0.11250734
# MedAE:  0.04818835
